# %%
import os
import pandas as pd
import numpy as np
import urllib
from datetime import datetime, timedelta
import itertools

# %%
today = str(datetime.now().strftime('%Y-%m-%d'))

# %%
path = (r'C:\Users\student\Documents\Alistair CoAgMET Projects\Pythonstuff\QC' +
        r'\data_exploration\diurnal_nocturnal_exploration\datasets')
os.chdir(path)

df = pd.read_csv(r"C:\Users\student\Documents\Alistair CoAgMET Projects\Pythonstuff\QC" +
                 r"\data_exploration\diurnal_nocturnal_exploration\datasets" +
                 r"\diurnal_nocturnal_explorationakr02_1992-07-01-2020-04-13.csv")

# %%
akr02 = {
    'drainage':'Kansas',
    'region':'North Plains',
    'id' : 'akr02',
    'lat': 40.1548,
    'long': -103.1420,
    'elevation': 4537,
    'fobs': '1992-07-01',
    'lobs': today,
    'irrigation':'Dry'
}

# %%
df['elevation'] = akr02['elevation']

# %%
akr02 = {
    'drainage':'Kansas',
    'region':'North Plains',
    'id' : 'akr02',
    'lat': 40.1548,
    'long': -103.1420,
    'elevation': 4537,
    'fobs': '1992-07-01',
    'lobs': today,
    'irrigation':'Dry',
}
alt01 = {
    'drainage':'Platte',
    'region':'North Front Range',
    'name': 'Ault',
    'id' : 'alt01',
    'lat' : 40.5690,
    'long': -104.72,
    'elevation' : 4910,
    'fobs' : '1992-05-17',
    'lobs': today,
    'irrigation' : 'Full'
}
avn01 = {
    'drainage' : 'Arkansas',
    'region' : 'West Valley Bottom',
    'name' : 'Avondale',
    'id' : 'avn01',
    'lat' : 38.2056,
    'long' : -104.3290,
    'elevation' : 4630,
    'fobs' : '1992-06-04',
    'lobs' : today,
    'irrigation' : 'Full'
}
bla01 = {
    'drainage' : 'Rio Grande',
    'region' : 'San Luis Valley',
    'name' : 'Blanca',
    'id' : 'bla01',
    'lat' : 37.3905,
    'long' : -105.5570,
    'elevation' : 7755,
    'fobs' : '1992-02-24',
    'lobs' : '2018-10-02',
    'irrigation' : 'Dry'
}
bnv01 = {
    'drainage' : 'Arkansas',
    'region' : 'Collegiate Valley',
    'name' : 'Buena Vista',
    'id' : 'bnv01',
    'lat' : 38.8315,
    'long' : -106.129,
    'elevation' : 7900,
    'fobs' : '2010-10-12',
    'lobs' : today,
    'irrigation' : 'Partial'
}
brg01 = {
    'drainage' : 'Platte',
    'region' : 'Lower Plains',
    'name' : 'Briggsdale',
    'id' : 'brg01',
    'lat' : 40.5947,
    'long' : -104.3190,
    'elevation' : 4858,
    'fobs' : '2002-07-31',
    'lobs' : today,
    'irrigation' : 'Dry'
}
brk01 = {
    'drainage' : 'Colorado',
    'region' : 'San Miguel',
    'name' : 'Bedrock',
    'id' : 'brk01',
    'lat' : 38.3279,
    'long' : -108.855,
    'elevation' : 4973,
    'fobs' : '2013-11-07',
    'lobs' : today,
    'irrigation' : 'Dry'
}
brl02 = {
    'drainage' : 'Kansas',
    'region' : 'South Plains',
    'name' : 'Burlington North',
    'id' : 'brl02',
    'lat' : 39.2651,
    'long' : -102.109,
    'elevation' : 4170,
    'fobs' : '1992-05-07',
    'lobs' : today,
    'irrigation' : 'Dry'  
}
brl03 = {
    'drainage' : 'Kansas',
    'region' : 'South Plains',
    'name' : 'Burlington 3',
    'id' : 'brl03',
    'lat' : 39.3374,
    'long' : -102.196,
    'elevation' : 4068,
    'fobs' : '2008-05-21',
    'lobs' : today,
    'irrigation' : 'Full'
}

cbl01 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Valley',
    'name' : 'Carbondale',
    'id' : 'cbl01',
    'lat' : 39.3623,
    'long' : -102.196,
    'elevation' : 6293,
    'fobs' : '2015-05-08',
    'lobs' : today,
    'irrigation' : 'Full'
}
cbn01 = {
    'drainage' : 'Colorado',
    'region' : 'Grand Valley',
    'name' : 'Collbran',
    'id' : 'cbn01',
    'lat' : 39.1993,
    'long' : -107.208,
    'elevation' : 6555,
    'fobs' : '2018-03-30',
    'lobs' : today,
    'irrigation' : 'Full'
}
ccr01 = {
    'drainage' : 'Platte',
    'region' : 'South Front Range',
    'name' : 'Cherry Creek Res',
    'id' : 'ccr01',
    'lat' : 39.6059,
    'long' : -104.834,
    'elevation' : 5632,
    'fobs' : '2019-07-25',
    'lobs' : today,
    'irrigation' : 'Dry'
}
cht01 = {
    'drainage' : 'Platte',
    'region' : 'South Front Range',
    'name' : 'Chatfield',
    'id' : 'cht01',
    'lat' : 39.5741,
    'long' : -105.054,
    'elevation' : 5414,
    'fobs' : '2019-12-04',
    'lobs' : today,
    'irrigation' : 'Dry'
}
ckp01 = {
    'drainage' : 'Platte',
    'region' : 'Front Range Foothills',
    'name' : 'Cherokee Park',
    'id' : 'ckp01',
    'lat' : 40.8263,
    'long' : -105.267,
    'elevation' : 5956,
    'fobs' : '2014-07-25',
    'lobs' : today,
    'irrigation' : 'Dry'
}
clk01 = {
    'drainage' : 'Colorado',
    'region' : 'Yampa',
    'name' : 'Clark',
    'id' : 'clk01',
    'lat' : 40.7043,
    'long' : -106.934,
    'elevation' : 7221,
    'fobs' : '2018-04-25',
    'lobs' : today,
    'irrigation' : 'Full'
}
cnn01 = {
    'drainage' : 'Arkansas',
    'region' : 'Mesas',
    'name' : 'Canon City',
    'id' : 'cnn01',
    'lat' : 38.4425,
    'long' : -105.176,
    'elevation' : 5344,
    'fobs' : '2010-12-31',
    'lobs' : today,
    'irrigation' : 'Partial'
}
cow01 = {
    'drainage' : 'Platte',
    'region' : 'North Park',
    'name' : 'Cowdry',
    'id' : 'cow01',
    'lat' : 40.8659,
    'long' : -106.336,
    'elevation' : 7895, 
    'fobs' : '2009-06-10',
    'lobs' : today,
    'irrigation' : 'Full'
}
ctr01 = {
    'drainage' : 'Rio Grande',
    'region' : 'San Luis Valley',
    'name' : 'Center',
    'id' : 'ctr01',
    'lat' : 37.7067,
    'long' : -106.144,
    'elevation' : 7702,
    'fobs' : '1993-10-08',
    'lobs' : today,
    'irrigation' : 'Partial'
}
ctz01 = {
    'drainage' : 'Colorado',
    'region' : 'Four Corners',
    'name' : 'Cortez',
    'id' : 'ctz01',
    'lat' : 37.2246,
    'long' : -108.673,
    'elevation' : 6015,
    'fobs' : '1992-01-02',
    'lobs' : today,
    'irrigation' : 'Full'
}
dlt01 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Gunnison',
    'name' : 'Delta',
    'id' : 'dlt01',
    'lat' : 37.7345,
    'long' : -108.119,
    'elevation' : 5010,
    'fobs' : '1995-04-19',
    'lobs' : today,
    'irrigation' : 'Partial'
}
drg01 = {
    'drainage' : 'Colorado',
    'region' : 'San Juan',
    'name' : 'Durango',
    'id' : 'drg01',
    'lat' : 37.1125,
    'long' : -107.881,
    'elevation' : 6203,
    'fobs' : '2018-05-30',
    'lobs' : today,
    'irrigation' : 'Full'
}
dvc01 = {
    'drainage' : 'Colorado',
    'region' : 'Four Corners',
    'name' : 'Dove Creek',
    'id' : 'dvc01',
    'lat' : 37.7265,
    'long' : -108.954,
    'elevation' : 6595,
    'fobs' : '1992-10-28',
    'lobs' : today,
    'irrigation' : 'Dry'
}
eac01 = {
    'drainage' : 'Platte',
    'region' : 'South Front Range',
    'name' : 'Eastern Adams County',
    'id' : 'eac01',
    'lat' : 39.7857,
    'long' : -103.789,
    'elevation' : 4907,
    'fobs' : '2000-07-17',
    'lobs' : today,
    'irrigation' : 'Dry'
}
egl01 = {
    'drainage' : 'Colorado',
    'region' : 'Eagle River Valley',
    'name' : 'Eagle',
    'id' : 'egl01',
    'lat' : 39.6308,
    'long' : -106.782,
    'elevation' : 6894,
    'fobs' : '2019-11-19',
    'lobs' : today,
    'irrigation' : 'Full'
}
ekt01 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Gunnison',
    'name' : 'Eckert',
    'id' : 'ekt01',
    'lat' : 38.8398,
    'long' : -107.973,
    'elevation' : 5522,
    'fobs' : '2015-05-07',
    'lobs' : today,
    'irrigation' : 'Full'
}
frt03 = {
    'drainage' : 'Colorado',
    'region' : 'Grand Valley',
    'name' : 'Fruita 3',
    'id' : 'frt03',
    'lat' : 39.183,
    'long' : -108.697,
    'elevation' : 4605,
    'fobs' : '2019-09-25',
    'lobs' : today,
    'irrigation' : 'Partial'
} 
ftc01 = {
    'drainage' : 'Platte',
    'region' : 'North Front Range',
    'name' : 'Fort Collins AERC',
    'id' : 'ftc01',
    'lat' : 40.5947,
    'long' : -105.137,
    'elevation' : 5120,
    'fobs' : '1992-02-01',
    'lobs' : today,
    'irrigation' : 'Partial'
}
ftc03 = {
    'drainage' : 'Platte',
    'region' : 'North Front Range',
    'name' : 'Fort Collins ARDEC',
    'id' : 'ftc03',
    'lat' : 40.3525,
    'long' : -105.0,
    'elevation' : 5110,
    'fobs' : '1992-05-08',
    'lobs' : today,
    'irrigation' : 'Partial'
}
fwl01 = {
    'drainage' : 'Arkansas',
    'region' : 'West Valley Bottom',
    'name' : 'Fowler',
    'id' : 'fwl01',
    'lat' : 38.1351,
    'long' : -104.032,
    'elevation' : 4335,
    'fobs' : '2005-05-17',
    'lobs' : today,
    'irrigation' : 'Full'
}
gby01 = {
    'drainage' : 'Colorado',
    'region' : 'Headwaters',
    'name' : 'Granby',
    'id' : 'gby01',
    'lat' : 40.1047,
    'long' : -105.943,
    'elevation' : 7911,
    'fobs' : '2019-04-23',
    'lobs' : today,
    'irrigation' : 'Full'
}
gly04 = {
    'drainage' : 'Platte',
    'region' : 'North Front Range',
    'name' : 'Greeley 4',
    'id' : 'gly04',
    'lat' : 40.4487,
    'long' : -104.683,
    'elevation' : 4683,
    'fobs' : '2008-06-05',
    'lobs' : today,
    'irrigation' : 'Full'
}
gun01 = {
    'drainage' : 'Colorado',
    'region' : 'Upper Gunnison',
    'name' : 'Gunnison',
    'id' : 'gun01',
    'lat' : 38.6135,
    'long' : -106.901,
    'elevation' : 7894,
    'fobs' : '2015-02-25',
    'lobs' : today,
    'irrigation' : 'Full'
}
gyp01 = {
    'drainage' : 'Colorado',
    'region' : 'Eagle River Valley',
    'name' : 'Gypsum',
    'id' : 'gyp01',
    'lat' : 39.6344,
    'long' : -106.901,
    'elevation' : 6470,
    'fobs' : '2017-10-11',
    'lobs' : today,
    'irrigation' : 'Partial'
}
heb01 = {
    'drainage' : 'Platte',
    'region' : 'North Park',
    'name' : 'Hebron',
    'id' : 'heb01',
    'lat' : 40.5455,
    'long' : -106.388,
    'elevation' : 8170,
    'fobs' : '2009-06-10',
    'lobs' : today,
    'irrigation' : 'Full'
}
hly01 = {
    'drainage' : 'Arkansas',
    'region' : 'East Valley Bottom',
    'name' : 'Holly',
    'id' : 'hly01',
    'lat' : 38.07,
    'long' : -102.09,
    'elevation' : 3636,
    'fobs' : '2001-09-27',
    'lobs' : today,
    'irrigation' : 'Partial'
}
hly02 = {
    'drainage' : 'Arkansas',
    'region' : 'East Valley Bottom',
    'name' : 'Holly 2',
    'id' : 'hly02',
    'lat' : 38.1361,
    'long' : -102.241,
    'elevation' : 3570,
    'fobs' : '2005-05-21',
    'lobs' : today,
    'irrigation' : 'Full'
}
hne01 = {
    'drainage' : 'Arkansas',
    'region' : 'Mesas',
    'name' : 'Hoehne',
    'id' : 'hne01',
    'lat' : 37.2893,
    'long' : -104.313,
    'elevation' : 5625,
    'fobs' : '2000-02-14',
    'lobs' : today,
    'irrigation' : 'Partial'
}
hot02 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Gunnison',
    'name' : 'Rogers Mesa 2',
    'id' : 'hot02',
    'lat' : 38.7985,
    'long' : -107.788,
    'elevation' : 5631,
    'fobs' : '2019-03-27',
    'lobs' : today,
    'irrigation' : 'Full'
}
hxt01 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Haxtun',
    'id' : 'hxt01',
    'lat' : 40.6722,
    'long' : -102.647,
    'elevation' : 4040,
    'fobs' : '1997-03-27',
    'lobs' : today,
    'irrigation' : 'Partial'
}
hyd01 = {
    'drainage' : 'Colorado',
    'region' : 'Yampa',
    'name' : 'Hayden',
    'id' : 'hyd01',
    'lat' : 40.499,
    'long' : -107.181,
    'elevation' : 6454,
    'fobs' : '2001-11-16',
    'lobs' : today,
    'irrigation' : 'Full'
}
hyk02 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Holyoke',
    'id' : 'hyk02',
    'lat' : 40.4909,
    'long' : -102.089,
    'elevation' : 3735,
    'fobs' : '1992-01-02',
    'lobs' : today,
    'irrigation' : 'Dry'
}
idl01 = {
    'drainage' : 'Kansas',
    'region' : 'South Plains',
    'name' : 'Idalia',
    'id' : 'idl01',
    'lat' : 39.7312,
    'long' : -102.302,
    'elevation' : 3975,
    'fobs' : '1992-01-02',
    'lobs' : today,
    'irrigation' : 'Full'
}
ign01 = {
    'drainage' : 'Colorado',
    'region' : 'San Juan',
    'name' : 'Ignacio',
    'id' : 'ign01',
    'lat' : 37.1383,
    'long' : -107.707,
    'elevation' : 6617,
    'fobs' : '2018-04-20',
    'lobs' : today,
    'irrigation' : 'Full'
}
ilf01 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Illif',
    'id' : 'ilf01',
    'lat' : 40.7678,
    'long' : -103.045,
    'elevation' : 3822,
    'fobs' : '2008-02-02',
    'lobs' : today,
    'irrigation' : 'Dry'
}
jfn01 = {
    'drainage' : 'Platte',
    'region' : 'South Park',
    'name' : 'Jefferson',
    'id' : 'jfn01',
    'lat' : 39.3509,
    'long' : -103.045,
    'elevation' : 3822,
    'fobs' : '2008-01-01',
    'lobs' : today,
    'irrigation' : 'Dry'
}
kln01 = {
    'drainage' : 'Colorado',
    'region' : 'San Juan',
    'name' : 'Kline',
    'id' : 'kln01',
    'lat' : 37.1261,
    'long' : -108.1460,
    'elevation' : 6755,
    'fobs' : '2018-04-12',
    'lobs' : today,
    'irrigation' : 'Partial'
}
krk01 = {
    'drainage' : 'Kansas',
    'region' : 'South Plains',
    'name' : 'Kirk',
    'id' : 'krk01',
    'lat' : 39.6554,
    'long' : -102.621,
    'elevation' : 4213,
    'fobs' : '1996-05-13',
    'lobs' : today,
    'irrigation' : 'Partial'
}
krm01 = {
    'drainage' : 'Colorado',
    'region' : 'Headwaters',
    'name' : 'Kremmling',
    'id' : 'krm01',
    'lat' : 40.1154,
    'long' : -106.283,
    'elevation' : 7534,
    'fobs' : '2018-04-30',
    'lobs' : today,
    'irrigation' : 'Full'
}
ksy01 = {
    'drainage' : 'Platte',
    'region' : 'Lower Plains',
    'name' : 'Kersey 1',
    'id' : 'ksy01',
    'lat' : 40.3768,
    'long' : -104.532,
    'elevation' : 4625,
    'fobs' : '1992-05-01',
    'lobs' : today,
    'irrigation' : 'Partial'
}
ksy02 = {
    'drainage' : 'Platte',
    'region' : 'Lower Plains',
    'name' : 'Kersey 2',
    'id' : 'ksy02',
    'lat' : 40.3629,
    'long' : -104.478,
    'elevation' : 4563,
    'fobs' : '2015-01-01',
    'lobs' : today,
    'irrigation' : 'Partial'
}
lam01 = {
    'drainage' : 'Arkansas',
    'region' : 'East Valley Bottom',
    'name' : 'Lamar 1',
    'id' : 'lam01',
    'lat' : 37.9807,
    'long' : -102.596,
    'elevation' : 3776,
    'fobs' : '1996-08-03',
    'lobs' : today,
    'irrigation' : 'Dry'
}
lam03 = {
    'drainage' : 'Arkansas',
    'region' : 'East Valley Bottom',
    'name' : 'Lamar 3',
    'id' : 'lam03',
    'lat' : 37.9798,
    'long' : -102.713,
    'fobs' : '2002-07-31',
    'lobs' : today,
    'irrigation' : 'Dry'
}
lam04 = {
    'drainage' : 'Arkansas',
    'region' : 'East Valley Bottom',
    'name' : 'Lamar 4',
    'id' : 'lam04',
    'lat' : 38.1539,
    'long' : -102.713,
    'elevation' : 3705,
    'fobs' : '2002-07-31',
    'lobs' : today,
    'irrigation' : 'Full'
}
lar01 = {
    'drainage' : 'Platte',
    'region' : 'North Park',
    'name' : 'Larand',
    'id' : 'lar01',
    'lat' : 40.6126,
    'long' : -106.3,
    'elevation' : 8252,
    'fobs' : '2009-06-10',
    'lobs' : today,
    'irrigation' : 'Full'
}
lcn01 = {
    'drainage' : 'Platte',
    'region' : 'North Front Range',
    'name' : 'Lucerne',
    'id' : 'lcn01',
    'lat' : 40.4756,
    'long' : -105.707,
    'elevation' : 4750,
    'fobs' : '1992-03-04',
    'lobs' : today,
    'irrigation' : 'Partial'
}
ljr01 = {
    'drainage' : 'Rio Grande',
    'region' : 'San Luis Valley',
    'name' : 'LaJara',
    'id' : 'ljr01',
    'lat' : 37.2443,
    'long' : -105.972,
    'elevation' : 7595,
    'fobs' : '2005-05-19',
    'lobs' : today,
    'irrigation' : 'Partial'
}
ljt01 = {
    'drainage' : 'Arkansas',
    'region' : 'West Valley Bottom',
    'name' : 'LaJunta',
    'id' : 'ljt01',
    'lat' : 37.0778,
    'long' : -103.366,
    'elevation' : 3960,
    'fobs' : '2012-03-17',
    'lobs' : today,
    'irrigation' : 'Full'
}
lsl01 = {
    'drainage' : 'Platte',
    'region' : 'South Front Range',
    'name' : 'La Salle',
    'id' : 'lsl01',
    'lat' : 40.3349,
    'long' : -104.63,
    'elevation' : 4676,
    'fobs' : '2012-02-10',
    'lobs' : today,
    'irrigation' : 'Partial'
}
mcl01 = {
    'drainage' : 'Arknasas',
    'region' : 'East Valley Bottom',
    'name' : 'McClave',
    'id' : 'mcl01',
    'lat' : 38.1475,
    'long' : -102.859,
    'elevation' : 3895,
    'fobs' : '2005-03-17',
    'lobs' : today,
    'irrigation' : 'Full'
}
mkr01 = {
    'drainage' : 'Colorado',
    'region' : 'Yampa',
    'name' : 'Meeker',
    'id' : 'mkr01',
    'lat' : 40.0083,
    'long' : -107.908,
    'elevation' : 6342,
    'fobs' : '2018-04-26',
    'lobs' : today,
    'irrigation' : 'Full'
}
mnc01 = {
    'drainage' : 'Colorado',
    'region' : 'Four Corners',
    'name' : 'Mancos',
    'id' : 'mnc01',
    'lat' : 37.3212,
    'long' : -108.339,
    'elevation' : 6730,
    'fobs' : '2010-10-29',
    'lobs' : today,
    'irrigation' : 'Full'
}
mtr01 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Gunnison',
    'name' : 'Montrose',
    'id' : 'mtr01',
    'lat' : 38.547,
    'long' : -107.914,
    'elevation' : 5651,
    'fobs' : '2015-02-24',
    'lobs' : today,
    'irrigation' : 'Full'
}
nwd01 = {
    'drainage' : 'Colorado',
    'region' : 'San Miguel',
    'name' : 'Norwood',
    'id' : 'nwd01',
    'lat' : 38.1510,
    'long' : -108.284,
    'elevation' : 7000,
    'fobs' : '2018-06-14',
    'lobs' : today,
    'irrigation' : 'Partial'
}
orm01 = {
    'drainage' : 'Colorado',
    'region' : 'Grand Valley',
    'name' : 'Orchard Mesa 1',
    'id' : 'orm01',
    'lat' : 39.0424,
    'long' : -108.466,
    'elevation' : 4700,
    'fobs' : '2006-01-02',
    'lobs' : '2019-09-24',
    'irrigation' : 'Partial'
}
oth01 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Gunnison',
    'name' : 'Olathe',
    'id' : 'oth01',
    'lat' : 38.6351,
    'long' : -107.964,
    'elevation' : 5324,
    'fobs' : '1992-07-28',
    'lobs' : today,
    'irrigation' : 'Partial'
}
pai01 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Paoli',
    'id' : 'pai01',
    'lat' : 40.4248,
    'long' : -102.475,
    'elevation' : 3875,
    'fobs' : '2001-09-26',
    'lobs' : today,
    'irrigation' : 'Dry'
}
pgs01 = {
    'drainage' : 'Colorado',
    'region' : 'San Juans',
    'name' : 'Pagosa Springs',
    'id' : 'pgs01',
    'lat' : 37.277,
    'long' : -106.983,
    'elevation' : 7181,
    'fobs' : '2018-04-20',
    'lobs' : today,
    'irrigation' : 'Full',    
}
pkh01 = {
    'drainage' : 'Platte',
    'region' : 'South Front Range',
    'name' : 'Peckham',
    'id' : 'pkh01',
    'lat' : 40.3125,
    'long' : -104.7270,
    'elevation' : 4701,
    'fobs' : '1992-03-17',
    'lobs' : today,
    'irrigation' : 'Partial'
}
pkr01 = {
    'drainage' : 'Platte',
    'region' : 'South Front Range',
    'name' : 'Parker',
    'id' : 'pkr01',
    'lat' : 39.5505,
    'long' : -104.811,
    'elevation' : 5813,
    'fobs' : '2015-03-12',
    'lobs' : '2019-07-24',
    'irrigation' : 'Dry'
}
pnr01 = {
    'drainage' : 'Arkansas',
    'region' : 'Mesas',
    'name' : 'Penrose',
    'id' : 'pnr01',
    'lat' : 38.4119,
    'long' : -104.998,
    'elevation' : 5331,
    'fobs' : '2010-10-13',
    'lobs' : today,
    'irrigation' : 'Full'
}
rfd01 = {
    'drainage' : 'East Valley Bottom',
    'region' : 'East Valley Bottom',
    'name' : 'Rocky Ford',
    'id' : 'rfd01',
    'lat' : 38.0385,
    'long' : -103.695,
    'fobs' : '1992-06-04',
    'lobs' : today,
    'irrigation' : 'Full'
}
san01 = {
    'drainage' : 'Rio Grande',
    'region' : 'Rocky Ford',
    'name' : 'San Acacio',
    'id' : 'san01',
    'lat' : 37.1417,
    'long' : -105.6110,
    'elevation' : 7753,
    'fobs' : '2000-08-12',
    'lobs' : today,
    'irrigation' : 'Dry'
}
sbt01 = {
    'drainage' : 'Kansas',
    'region' : 'South Plains',
    'name' : 'Seibert',
    'id' : 'sbt01',
    'lat' : 39.1187,
    'long' : -102.925,
    'elevation' : 4852,
    'fobs' : '2015-04-02',
    'lobs' : today,
    'irrigation' : 'Dry'
}
scm01 = {
    'drainage' : 'Arkansas',
    'region' : 'North of Valley',
    'name' : 'Sand Creek',
    'id' : 'scm01',
    'lat' : 38.5439,
    'long' : -102.503,
    'elevation' : 3963,
    'fobs' : '2008-07-24',
    'lobs' : today,
    'irrigation' : 'Dry'
}
sld01 = {
    'drainage' : 'Arkansas',
    'region' : 'Collegiate Valley',
    'name' : 'Salida',
    'id' : 'sld01',
    'lat' : 38.5713,
    'long' : -102.043,
    'elevation' : 7227,
    'fobs' : '2010-07-28',
    'lobs' : today,
    'irrigation' : 'Full'
}
slt01 = {
    'drainage' : 'Colorado',
    'region' : 'Lower Valley',
    'name' : 'Silt',
    'id' : 'slt01',
    'lat' : 39.5713,
    'long' : -107.693,
    'elevation' : 5620,
    'fobs' : '2015-05-08',
    'lobs' : today,
    'irrigation' : 'Full'
}
stg01 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Sterling',
    'id' : 'stg01',
    'lat' : 40.4632,
    'long' : -103.028,
    'elevation' : 4472,
    'fobs' : '2006-03-24',
    'lobs' : today,
    'irrigation' : 'Dry'
}
stn01 = {
    'drainage' : 'Kansas',
    'region' : 'South Plains',
    'name' : 'Stratton',
    'id' : 'stn01',
    'lat' : 39.2987,
    'long' : -102.522,
    'elevation' : 4321,
    'fobs' : '2006-04-01',
    'lobs' : today,
    'irrigation' : 'Dry'
}
twc01 = {
    'drainage' : 'Colorado',
    'region' : 'Four Corners',
    'name' : 'Towaoc',
    'id' : 'twc01',
    'lat' : 37.1891,
    'long' : -108.935,
    'elevation' : 5319,
    'fobs' : '1998-06-30',
    'lobs' : today,
    'irrigation' : 'Partial'
}
wcf01 = {
    'drainage' : 'Arkansas',
    'region' : 'Mesas',
    'name' : 'Westcliffe',
    'id' : 'wcf01',
    'lat' : 38.1504,
    'long' : -105.499,
    'elevation' : 7734,
    'fobs' : '2010-09-20',
    'lobs' : today,
    'irrigation' : 'Full'
}
wfd01 = {
    'drainage' : 'Colorado',
    'region' : 'Headwaters',
    'name' : 'Wolford Mountain Reservoir',
    'id' : 'wfd01',
    'lat' : 40.1387,
    'long' : -106.415,
    'elevation' : 7520,
    'fobs' : '2004-11-30',
    'lobs' : today,
    'irrigation' : 'Dry'
}
wls01 = {
    'drainage' : 'Arkansas',
    'region' : 'Plateau South of Valley',
    'name' : 'Walsh',
    'id' : 'wls01',
    'lat' : 37.383,
    'long' : -102.294,
    'elevation' : 3974,
    'fobs' : '2012-04-11',
    'lobs' : today,
    'irrigation' : 'Dry'
}
wry02 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Wray 2',
    'id' : 'wry02',
    'lat' : 40.2187,
    'long' : -102.265,
    'elevation' : 3736,
    'fobs' : '2015-04-01',
    'lobs' : today,
    'irrigation' : 'Full'
}
yjk01 = {
    'drainage' : 'Colorado',
    'region' : 'Four Corners',
    'name' : 'Yellowjacket',
    'id' : 'yjk01',
    'lat' : 37.5428,
    'long' : -108.74,
    'elevation' : 6900,
    'fobs' : '1992-01-02',
    'lobs' : today,
    'irrigation' : 'Full'
}
yuc01 = {
    'drainage' : 'Colorado',
    'region' : 'Four Corners',
    'name' : 'Yucca House',
    'id' : 'yuc01',
    'lat' : 37.2478,
    'long' : -108.6870,
    'elevation' : 5975,
    'fobs' : '2002-08-23',
    'lobs' : today,
    'irrigation' : 'Dry'
}
yum02 = {
    'drainage' : 'Kansas',
    'region' : 'North Plains',
    'name' : 'Yuma 2',
    'id' : 'yum02',
    'lat' : 40.1504,
    'long' : -102.7240,
    'elevation' : 4104,
    'fobs' : '1996-05-08',
    'lobs' : today,
    'irrigation' : 'Full'
}

# %%
stationlist = [akr02,alt01,avn01,bla01,bnv01,brg01,brk01,brl02,brl03,cbl01,cbn01,ccr01,cht01,ckp01,
              clk01,cnn01,cow01,ctr01,ctz01,dlt01,drg01,dvc01,eac01,egl01,ekt01,frt03,ftc01,ftc03,
              fwl01,gby01,gly04,gun01,gyp01,heb01,hly01,hly02,hne01,hot02,hxt01,hyd01,hyk02,idl01,
              ign01,ilf01,jfn01,kln01,krk01,krm01,ksy01,ksy02,lam01,lam03,lam04,lar01,lcn01,ljr01,
              ljt01,lsl01,mcl01,mkr01,mnc01,mtr01,nwd01,orm01,oth01,pai01,pgs01,pkh01,pkr01,pnr01,
              rfd01,san01,sbt01,scm01,sld01,slt01,stg01,stn01,twc01,wcf01,wfd01,wls01,wry02,yjk01,
              yuc01,yum02]

# %%
filelist = os.listdir(path)

stations_and_files = list(zip(stationlist,filelist))

# %%
stations_and_files
# Out:
# [({'drainage': 'Kansas',
#    'region': 'North Plains',
#    'id': 'akr02',
#    'lat': 40.1548,
#    'long': -103.142,
#    'elevation': 4537,
#    'fobs': '1992-07-01',
#    'lobs': '2020-04-22',
#    'irrigation': 'Dry',
#    'file': 'diurnal_nocturnal_explorationakr02_1992-07-01-2020-04-13.csv'},
#   'diurnal_nocturnal_explorationakr02_1992-07-01-2020-04-13.csv'),
#  ({'drainage': 'Platte',
#    'region': 'North Front Range',
#    'name': 'Ault',
#    'id': 'alt01',
#    'lat': 40.569,
#    'long': -104.72,
#    'elevation': 4910,
#    'fobs': '1992-05-17',
#    'lobs': '2020-04-22',
#    'irrigation': 'Full',
#    'file': 'diurnal_nocturnal_explorationalt01_1992-05-17-2020-04-13.csv'},
#   'diurnal_nocturnal_explorationalt01_1992-05-17-2020-04-13.csv'),
#  ({'drainage': 'Arkansas',
#    'region': 'West Valley Bottom',
#    'name': 'Avondale',
#    'id': 'avn01',
#    'lat': 38.2056,
#    'long': -104.329,
#    'elevation': 4630,
#    'fobs': '1992-06-04',
# ...

# %%
def update_stations(dictionary,file):
    dictionary['file'] = file

# %%
for x in stations_and_files:
    update_stations(x[0],x[1])

# %%
df = itertools.starmap(update_stations,stations_and_files)

# %%
print(list(df))
# Out:
# []

# %%
akr02
# Out:
# {'drainage': 'Kansas',
#  'region': 'North Plains',
#  'id': 'akr02',
#  'lat': 40.1548,
#  'long': -103.142,
#  'elevation': 4537,
#  'fobs': '1992-07-01',
#  'lobs': '2020-04-22',
#  'irrigation': 'Dry',
#  'file': 'diurnal_nocturnal_explorationakr02_1992-07-01-2020-04-13.csv'}

# %%
def add_
