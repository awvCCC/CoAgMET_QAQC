# %%
# Loads the libraries required to build the environment we will be using in this tutorial
import os
import urllib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from scipy import stats
import calendar

# %%
path = r'C:\Users\student\Documents\Alistair CoAgMET Projects\Pythonstuff\QC\normals'
os.chdir(path)

xlsx = r"C:\Users\student\Documents\Alistair CoAgMET Projects\Pythonstuff\QC\metadata.xlsx"

xsls_file = pd.ExcelFile(xlsx)
xsls_file.sheet_names
# Out:
# ['metadata']

# %%
df= xsls_file.parse('metadata')
df
# Out:
#        ID      sdate      edate
# 0   AKR02 1992-07-01 2019-08-26
# 1   ALT01 1992-03-17 2019-08-26
# 2   AVN01 1992-06-04 2019-08-26
# 3   BNV01 2010-10-12 2019-08-26
# 4   BRG01 2002-07-31 2019-08-26
# ..    ...        ...        ...
# 80  WLS01 2012-04-11 2019-08-26
# 81  WRY02 2015-04-01 2019-08-26
# 82  YJK01 1992-01-02 2019-08-26
# 83  YUC01 2002-08-23 2019-08-26
# 84  YUM02 1996-05-08 2019-08-26
#
# [85 rows x 3 columns]

# %%
df['sdate'] = pd.to_datetime(df.sdate)

# %%
df['sdate'] = df.sdate.dt.date

# %%
df['edate'] = df.edate.dt.date

# %%
n=0
for index,rows in df.iterrows():
    print(str(df['ID'][n]) + 'began collecting data on ' + str(df['sdate'][n]))
    n = n+1
# Out:
# AKR02began collecting data on 1992-07-01
# ALT01began collecting data on 1992-03-17
# AVN01began collecting data on 1992-06-04
# BNV01began collecting data on 2010-10-12
# BRG01began collecting data on 2002-07-31
# BRK01began collecting data on 2013-11-07
# BRL02began collecting data on 1992-01-02
# BRL03began collecting data on 2008-03-21
# CBL01began collecting data on 2015-05-08
# CBN01began collecting data on 2018-03-30
# CCR01began collecting data on 2019-07-25
# CKP01began collecting data on 2014-07-25
# CLK01began collecting data on 2018-04-25
# CNN01began collecting data on 2010-12-31
# COW01began collecting data on 2009-06-10
# CTR01began collecting data on 1993-10-08
# CTR02began collecting data on 2003-10-02
# CTZ01began collecting data on 1992-01-02
# DLT01began collecting data on 1995-04-19
# DRG01began collecting data on 2018-05-30
# DVC01began collecting data on 1992-10-28
# EAC01began collecting data on 2000-07-17
# EKT01began collecting data on 2015-05-07
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f28700208c36> in <module>
# ----> 1 for ID, sdate, edate in dictionary.items():
#       2     print(ID + 'began reporting data in ' + str(sdate) + ' and the stations last report occurred on ' + str(edate))
#
# ValueError: not enough values to unpack (expected 3, got 2)
